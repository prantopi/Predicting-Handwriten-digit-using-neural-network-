# %% [markdown]
# <a href="https://colab.research.google.com/github/prantopi/Predicting-Handwriten-digit-using-neural-network-/blob/main/Untitled_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np

# %%
(X_train,y_train),(X_test,y_test)=keras.datasets.mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
print(len(X_train),len(X_test),X_train[0].shape)
X_train=X_train/255
X_test=X_test/255
# Out:
# 60000 10000 (28, 28)

# %%
plt.matshow(X_train[5])

# %%
model=keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(100,activation="relu"),
    keras.layers.Dense(10,activation="sigmoid")
])
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.fit(X_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2695 - accuracy: 0.9229
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1199 - accuracy: 0.9642
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0840 - accuracy: 0.9744
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0642 - accuracy: 0.9801
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0501 - accuracy: 0.9843

# %%
model.evaluate(X_test,y_test)

y_predicted=model.predict(X_test)
print(y_predicted[5])
print(np.argmax(y_predicted[5]))

y_predicted_labels=[np.argmax(i) for i in y_predicted]
# Out:
# ...
# 313/313 [==============================] - 1s 2ms/step
# [1.6247592e-04 9.9952257e-01 3.3360403e-02 3.1717224e-03 3.6566209e-02
#  1.8297204e-04 7.1277778e-04 8.9932954e-01 4.7366176e-02 1.9165857e-03]
# 1

# %%
cm=tf.math.confusion_matrix(labels=y_test,predictions=y_predicted_labels)
print(cm)
# Out:
# tf.Tensor(
# [[ 972    0    0    0    2    0    2    1    3    0]
#  [   0 1123    6    0    0    1    2    1    2    0]
#  [   7    2 1008    0    1    0    4    5    4    1]
#  [   0    0   10  973    1   15    0    5    4    2]
#  [   2    0    2    0  958    1    5    1    0   13]
#  [   3    0    0    1    1  880    3    0    3    1]
#  [   9    2    0    0    4    1  941    1    0    0]
#  [   2    3   10    1    0    0    0 1003    3    6]
#  [  10    1    4    3    4    7    3    5  932    5]
#  [   8    5    0    4    8    5    1    6    0  972]], shape=(10, 10), dtype=int32)

# %%
import seaborn as sn

plt.figure(figsize=(10,7))
sn.heatmap(cm,annot=True,fmt="d")
plt.xlabel("Predicted")
plt.ylabel("True")
# Out:
# Text(95.72222222222221, 0.5, 'True')
